# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv('dataset.csv')

# %%
dataset.head()
# Out:
#   Reference Number  Grid Ref: Easting  Grid Ref: Northing  Number of Vehicles  \
# 0          1112091             429175              431904                   2
# 1          1180869             430429              431025                   3
# 2          1180869             430429              431025                   3
# 3          11A0238             424660              427582                   3
# 4          11A0238             424660              427582                   3
#
#    Number of Casualties Accident Date  Time (24hr)  1st Road Class  \
# 0                     1    01/01/2014         1840               6
# 1                     2    08/01/2014         1430               1
# 2                     2    08/01/2014         1430               1
# 3                     2    10/01/2014          817               1
# 4                     2    10/01/2014          817               1
#
#    Road Surface  Lighting Conditions  Weather Conditions  Casualty Class  \
# 0             2                    4                   2               1
# 1             2                    1                   1               1
# 2             2                    1                   1               1
# 3             1                    1                   1               1
# 4             1                    1                   1               1
#
#    Casualty Severity  Sex of Casualty  Age of Casualty  Type of Vehicle
# 0                  3                1               58                9
# 1                  3                1               69                9
# 2                  3                2               41                9
# 3                  3                1               35                9
# 4                  3                1               25                9

# %%
x=dataset.iloc[:,3:]
x.head()
# Out:
#    Number of Vehicles  Number of Casualties Accident Date  Time (24hr)  \
# 0                   2                     1    01/01/2014         1840
# 1                   3                     2    08/01/2014         1430
# 2                   3                     2    08/01/2014         1430
# 3                   3                     2    10/01/2014          817
# 4                   3                     2    10/01/2014          817
#
#    1st Road Class  Road Surface  Lighting Conditions  Weather Conditions  \
# 0               6             2                    4                   2
# 1               1             2                    1                   1
# 2               1             2                    1                   1
# 3               1             1                    1                   1
# 4               1             1                    1                   1
#
#    Casualty Class  Casualty Severity  Sex of Casualty  Age of Casualty  \
# 0               1                  3                1               58
# 1               1                  3                1               69
# 2               1                  3                2               41
# 3               1                  3                1               35
# 4               1                  3                1               25
#
#    Type of Vehicle
# 0                9
# 1                9
# 2                9
# 3                9
# 4                9

# %%
x.drop(columns='Number of Casualties',inplace=True)
x.head()
# Out:
#    Number of Vehicles Accident Date  Time (24hr)  1st Road Class  \
# 0                   2    01/01/2014         1840               6
# 1                   3    08/01/2014         1430               1
# 2                   3    08/01/2014         1430               1
# 3                   3    10/01/2014          817               1
# 4                   3    10/01/2014          817               1
#
#    Road Surface  Lighting Conditions  Weather Conditions  Casualty Class  \
# 0             2                    4                   2               1
# 1             2                    1                   1               1
# 2             2                    1                   1               1
# 3             1                    1                   1               1
# 4             1                    1                   1               1
#
#    Casualty Severity  Sex of Casualty  Age of Casualty  Type of Vehicle
# 0                  3                1               58                9
# 1                  3                1               69                9
# 2                  3                2               41                9
# 3                  3                1               35                9
# 4                  3                1               25                9

# %%
x.drop(columns='Time (24hr)',inplace=True)
x.head()
# Out:
#    Number of Vehicles Accident Date  1st Road Class  Road Surface  \
# 0                   2    01/01/2014               6             2
# 1                   3    08/01/2014               1             2
# 2                   3    08/01/2014               1             2
# 3                   3    10/01/2014               1             1
# 4                   3    10/01/2014               1             1
#
#    Lighting Conditions  Weather Conditions  Casualty Class  Casualty Severity  \
# 0                    4                   2               1                  3
# 1                    1                   1               1                  3
# 2                    1                   1               1                  3
# 3                    1                   1               1                  3
# 4                    1                   1               1                  3
#
#    Sex of Casualty  Age of Casualty  Type of Vehicle
# 0                1               58                9
# 1                1               69                9
# 2                2               41                9
# 3                1               35                9
# 4                1               25                9

# %%
x.drop(columns='Accident Date',inplace=True)
x.head()
# Out:
#    Number of Vehicles  1st Road Class  Road Surface  Lighting Conditions  \
# 0                   2               6             2                    4
# 1                   3               1             2                    1
# 2                   3               1             2                    1
# 3                   3               1             1                    1
# 4                   3               1             1                    1
#
#    Weather Conditions  Casualty Class  Casualty Severity  Sex of Casualty  \
# 0                   2               1                  3                1
# 1                   1               1                  3                1
# 2                   1               1                  3                2
# 3                   1               1                  3                1
# 4                   1               1                  3                1
#
#    Age of Casualty  Type of Vehicle
# 0               58                9
# 1               69                9
# 2               41                9
# 3               35                9
# 4               25                9

# %%
x.isnull().any()
# Out:
# Number of Vehicles     False
# 1st Road Class         False
# Road Surface           False
# Lighting Conditions    False
# Weather Conditions     False
# Casualty Class         False
# Casualty Severity      False
# Sex of Casualty        False
# Age of Casualty        False
# Type of Vehicle        False
# dtype: bool

# %%
y=dataset.iloc[:,4]

# %%
y.head()
# Out:
# 0    1
# 1    2
# 2    2
# 3    2
# 4    2
# Name: Number of Casualties, dtype: int64

# %%
y.isnull().any()
# Out:
# False

# %%
x=x.values

# %%
x
# Out:
# array([[ 2,  6,  2, ...,  1, 58,  9],
#        [ 3,  1,  2, ...,  1, 69,  9],
#        [ 3,  1,  2, ...,  2, 41,  9],
#        ...,
#        [ 1,  6,  1, ...,  1, 71,  8],
#        [ 1,  6,  1, ...,  1, 23,  9],
#        [ 2,  6,  1, ...,  1, 77, 22]], dtype=int64)

# %%
y=y.values

# %%
y
# Out:
# array([1, 2, 2, ..., 1, 1, 1], dtype=int64)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn.preprocessing import MinMaxScaler
sc=MinMaxScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
import seaborn as sns
